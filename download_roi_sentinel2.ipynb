# %%
import planetary_computer as pc
import pystac_client
from pystac_client import Client
import geopandas as gpd
import rasterio
import rioxarray
from rasterio.windows import Window
from rasterio.mask import mask
import leafmap
from shapely.geometry import box, mapping
from pystac.extensions.eo import EOExtension as eo
import os

# %%
def create_grid(bounds, grid_size):
    minx, miny, maxx, maxy = bounds
    grid = []
    x = minx
    while x < maxx:
        y = miny
        while y < maxy:
            grid.append(box(x, y, x + grid_size, y + grid_size))
            y += grid_size
        x += grid_size
    return grid

# %%
def get_pv_roi(shp_path, grid_size):
    # 读取shp文件
    gdf = gpd.read_file(shp_path)
    
    # 获取shp文件的边界
    bounds = gdf.total_bounds
    
    # 创建网格
    grid = create_grid(bounds, grid_size)
    
    # 创建一个新的GeoDataFrame来存储bbox
    grid_gdf = gpd.GeoDataFrame({'geometry': grid})
    # 过滤掉不与面矢量相交的bbox
    grid_gdf = grid_gdf[grid_gdf.intersects(gdf.unary_union)]
    
    # 保存结果到新的shp文件
    grid_gdf.to_file('pv_roi_0.1_grid.shp')

# %%
def download_planetary_computer_image(bbox, time_range, cloud_cover_threshold=10, band="visual", output_file="output.tif"):
    """
    下载指定区域和时间范围内的Planetary Computer影像数据。

    参数：
    - bbox: 研究区域的边界框，格式为 [min_lon, min_lat, max_lon, max_lat]
    - time_range: 时间范围，格式为 "YYYY-MM-DD/YYYY-MM-DD"
    - cloud_cover_threshold: 云覆盖率阈值，默认为10%
    - band: 要下载的波段，默认为 "visual"
    - output_file: 输出文件名，默认为 "output.tif"
    """
    # 打开STAC客户端
    catalog = pystac_client.Client.open(
        "https://planetarycomputer.microsoft.com/api/stac/v1",
        modifier=pc.sign_inplace,
    )

    # 搜索数据
    search = catalog.search(
        collections=["sentinel-2-l2a"],
        bbox=bbox,
        datetime=time_range,
        query={"eo:cloud_cover": {"lt": cloud_cover_threshold}},
    )
    items = search.item_collection()

    # 选择云覆盖率最低的数据项
    from pystac.extensions.eo import EOExtension as eo
    selected_item = min(items, key=lambda item: eo.ext(item).cloud_cover)

    # 读取影像波段并导出
    xds = rioxarray.open_rasterio(selected_item.assets[band].href)

    # 创建裁剪用的GeoDataFrame
    geom = box(*bbox)
    gdf = gpd.GeoDataFrame({"geometry": [geom]}, crs="EPSG:4326")

    # 裁剪影像
    xds_clipped = xds.rio.clip(gdf.geometry.apply(mapping), gdf.crs)

    xds_clipped.rio.to_raster(output_file, compress='LZW', tiled=True, dtype="uint8")

    print(f"影像已下载并保存为 {output_file}")

# %%
def download_index(roi,out_dir,time_range="2023-01-01/2023-12-31",index_range=None):
    roi_gdf = gpd.read_file(roi)
    if index_range==None:
        index_range = list(range(0, len(roi_gdf)-1))
    for index, row in roi_gdf.iterrows():
        if index in index_range:
            geometry = row['geometry']
            bbox = geometry.bounds
            savefile = os.path.join(out_dir,f"{index}.tif")
            download_planetary_computer_image(bbox=bbox,time_range=time_range, output_file=savefile)

# roi_gdf = gpd.read_file('pv_roi_0.1_grid.shp')
# # 逐个读取要素
# for index, row in roi_gdf.iterrows():
#     geometry = row['geometry']
#     bbox = geometry.bounds
#     savefile="./test/"+f"{index}.tif"

#     if index==8000:
#         print(bbox)
#     # print(f"Feature {index}: {geometry}")
#         download_planetary_computer_image(bbox=bbox,time_range="2023-01-01/2023-12-31", output_file=savefile)

# %%
if __name__ == "__main__":
    shp_path = '../Data/Road/GRIP4_density_total/pv_roi/pv_roi.shp'
    grid_size = 1  # 根据需要调整网格大小
    # 需要约80分钟
    # get_pv_roi(shp_path, grid_size)
    roi = 'pv_roi_1_grid.shp'
    # index_range = list(range(8000, 10000))
    download_index(roi, out_dir='E:\PV_Global\data\sentinel2_2023_pc')
# Out:
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\0.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\1.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\2.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\3.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\4.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\5.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\6.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\7.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\8.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\9.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\10.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\11.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\12.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\13.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\14.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\15.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\16.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\17.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\18.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\19.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\20.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\21.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\22.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\23.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\24.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\25.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\26.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\27.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\28.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\29.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\30.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\31.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\32.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\33.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\34.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\35.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\36.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\37.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\38.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\39.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\40.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\41.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\42.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\43.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\44.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\45.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\46.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\47.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\48.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\49.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\50.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\51.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\52.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\53.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\54.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\55.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\56.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\57.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\58.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\59.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\60.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\61.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\62.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\63.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\64.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\65.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\66.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\67.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\68.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\69.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\70.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\71.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\72.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\73.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\74.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\75.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\76.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\77.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\78.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\79.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\80.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\81.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\82.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\83.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\84.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\85.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\86.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\87.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\88.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\89.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\90.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\91.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\92.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\93.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\94.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\95.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\96.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\97.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\98.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\99.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\100.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\101.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\102.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\103.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\104.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\105.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\106.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\107.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\108.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\109.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\110.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\111.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\112.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\113.tif
# 影像已下载并保存为 E:\PV_Global\data\sentinel2_2023_pc\114.tif
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[6], line 8
#       6 roi = 'pv_roi_1_grid.shp'
#       7 # index_range = list(range(8000, 10000))
# ----> 8 download_index(roi, out_dir='E:\PV_Global\data\sentinel2_2023_pc')
#
# Cell In[5], line 10, in download_index(roi, out_dir, time_range, index_range)
#       8 bbox = geometry.bounds
#       9 savefile = os.path.join(out_dir,f"{index}.tif")
# ---> 10 download_planetary_computer_image(bbox=bbox,time_range=time_range, output_file=savefile)
#
# Cell In[4], line 25, in download_planetary_computer_image(bbox, time_range, cloud_cover_threshold, band, output_file)
#      18 # 搜索数据
#      19 search = catalog.search(
#      20     collections=["sentinel-2-l2a"],
#      21     bbox=bbox,
#      22     datetime=time_range,
#      23     query={"eo:cloud_cover": {"lt": cloud_cover_threshold}},
#      24 )
# ---> 25 items = search.item_collection()
#      27 # 选择云覆盖率最低的数据项
#      28 from pystac.extensions.eo import EOExtension as eo
#
# File d:\ProgramData\miniconda3\envs\pc\Lib\site-packages\pystac_client\item_search.py:766, in ItemSearch.item_collection(self)
#     758 """
#     759 Get the matching items as a :py:class:`pystac.ItemCollection`.
#     760
#     761 Return:
#     762     ItemCollection: The item collection
#     763 """
#     764 # Bypass the cache here, so that we can pass __preserve_dict__
#     765 # without mutating what's in the cache.
# --> 766 feature_collection = self.item_collection_as_dict.__wrapped__(self)
#     767 # already signed in item_collection_as_dict
#     768 return ItemCollection.from_dict(
#     769     feature_collection, preserve_dict=False, root=self.client
#     770 )
#
# File d:\ProgramData\miniconda3\envs\pc\Lib\site-packages\pystac_client\item_search.py:787, in ItemSearch.item_collection_as_dict(self)
#     774 """
#     775 Get the matching items as an item-collection-like dict.
#     776
#    (...)
#     784     Dict : A GeoJSON FeatureCollection
#     785 """
#     786 features = []
# --> 787 for page in self.pages_as_dicts():
#     788     for feature in page["features"]:
#     789         features.append(feature)
#
# File d:\ProgramData\miniconda3\envs\pc\Lib\site-packages\pystac_client\item_search.py:737, in ItemSearch.pages_as_dicts(self)
#     735 if isinstance(self._stac_io, StacApiIO):
#     736     num_items = 0
# --> 737     for page in self._stac_io.get_pages(
#     738         self.url, self.method, self.get_parameters()
#     739     ):
#     740         call_modifier(self.modifier, page)
#     741         features = page.get("features", [])
#
# File d:\ProgramData\miniconda3\envs\pc\Lib\site-packages\pystac_client\stac_api_io.py:308, in StacApiIO.get_pages(self, url, method, parameters)
#     296 def get_pages(
#     297     self,
#     298     url: str,
#     299     method: Optional[str] = None,
#     300     parameters: Optional[Dict[str, Any]] = None,
#     301 ) -> Iterator[Dict[str, Any]]:
#     302     """Iterator that yields dictionaries for each page at a STAC paging
#     303     endpoint, e.g., /collections, /search
#     304
#     305     Return:
#     306         Dict[str, Any] : JSON content from a single page
#     307     """
# --> 308     page = self.read_json(url, method=method, parameters=parameters)
#     309     if not (page.get("features") or page.get("collections")):
#     310         return None
#
# File d:\ProgramData\miniconda3\envs\pc\Lib\site-packages\pystac\stac_io.py:206, in StacIO.read_json(self, source, *args, **kwargs)
#     189 def read_json(self, source: HREF, *args: Any, **kwargs: Any) -> dict[str, Any]:
#     190     """Read a dict from the given source.
#     191
#     192     See :func:`StacIO.read_text <pystac.StacIO.read_text>` for usage of
#    (...)
#     204         given source.
#     205     """
# --> 206     txt = self.read_text(source, *args, **kwargs)
#     207     return self.json_loads(txt)
#
# File d:\ProgramData\miniconda3\envs\pc\Lib\site-packages\pystac_client\stac_api_io.py:171, in StacApiIO.read_text(self, source, *args, **kwargs)
#     169 href = str(source)
#     170 if _is_url(href):
# --> 171     return self.request(href, *args, **kwargs)
#     172 else:
#     173     with open(href) as f:
#
# File d:\ProgramData\miniconda3\envs\pc\Lib\site-packages\pystac_client\stac_api_io.py:223, in StacApiIO.request(self, href, method, headers, parameters)
#     221     raise APIError(str(err))
#     222 if resp.status_code != 200:
# --> 223     raise APIError.from_response(resp)
#     224 try:
#     225     return resp.content.decode("utf-8")
#
# APIError: The request exceeded the maximum allowed time, please try again. If the issue persists, please contact planetarycomputer@microsoft.com.
